# %% [markdown]
# # Image Classification with CNN - LeNet5 architecture

# %% [markdown]
# In this exercise, we will apply the LeNet5 algorithm to the Fashion MNIST dataset and improve your performances.

# %% [markdown]
# We will first download the data:

# %%
# TODO: Load the dataset
from tensorflow.keras.datasets import fashion_mnist

(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()

# # # If your computer is slow, try to use a subset of data, e.g.
# X_train = X_train[:10000]
# y_train = y_train[:10000]
# X_test = X_test[:2000]
# y_test = y_test[:2000]
X_train.shape
# Out:
# (60000, 28, 28)

# %% [markdown]
# As you already know, this dataset contains 10 classes:
# * 0:	T-shirt/top
# * 1:	Trouser
# * 2:	Pullover
# * 3:	Dress
# * 4:	Coat
# * 5:	Sandal
# * 6:	Shirt
# * 7:	Sneaker
# * 8:	Bag
# * 9:	Ankle boot

# %% [markdown]
# You can have a look at some images if needed, even if you already know them.

# %%
# TODO: Explore the data, display some input images
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

label_class = ['top', 'trouser', 'pullover', 'dress', 'coat', 'sandal', 'shirt', 'sneaker', 'bag', 'ankle boot']

idx = np.random.randint(X_train.shape[0])

plt.imshow(X_train[idx], cmap="gray_r")
plt.title(label_class[y_train[idx]])
plt.show()

# %% [markdown]
# Make the data preparation and preprocessing: scale and reshape the data, put the labels to the good shape.

# %%
# TODO: Make the data preparation
from tensorflow.keras.utils import to_categorical

y_train_cat = to_categorical(y_train, num_classes=10)
y_test_cat = to_categorical(y_test, num_classes=10)

X_train_norm = X_train/255
X_test_norm = X_test/255


X_train_norm = X_train_norm.reshape(X_train_norm.shape[0], 28, 28, 1)
X_test_norm = X_test_norm.reshape(X_test_norm.shape[0], 28, 28, 1)

X_train_norm.shape #Should be (60000, 28, 28, 1)
# Out:
# (60000, 28, 28, 1)

# %% [markdown]
# Now build the LeNet5 architecture. You can reuse the one of the course, or try to build it by yourself.
#
# The architecture is the following:
#
# <p align="center">
# <img src="https://drive.google.com/uc?export=view&id=1WteTU2FPIVMkBKmMxGpFm5OjsX-szTbB">
# </p>

# %%
# TODO: Build your model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import MaxPooling2D, Conv2D, Flatten, Dense


def lenet5():

    model = Sequential()

    # Layer C1
    model.add(Conv2D(filters=6, name='C1', kernel_size=(3, 3), activation='relu', input_shape=(28,28,1)))
    # Layer S2
    model.add(MaxPooling2D(pool_size=(2, 2), name='S2'))
    # Layer C3
    model.add(Conv2D(filters=16, name='C3', kernel_size=(3, 3), activation='relu'))
    # Layer S4
    model.add(MaxPooling2D(pool_size=(2, 2), name='S4'))
    # Before going into layer C5, we flatten our units
    model.add(Flatten())
    # Layer C5
    model.add(Dense(120, activation = "relu", name="C5"))
    # Layer F6
    model.add(Dense(84, activation = "relu", name="F6"))
    # Output layer
    model.add(Dense(units=10, activation = 'softmax'))

    return model
lenet5().summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ C1 (Conv2D)                     │ (None, 26, 26, 6)      │            60 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ S2 (MaxPooling2D)               │ (None, 13, 13, 6)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ C3 (Conv2D)                     │ (None, 11, 11, 16)     │           880 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ S4 (MaxPooling2D)               │ (None, 5, 5, 16)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_6 (Flatten)             │ (None, 400)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ C5 (Dense)                      │ (None, 120)            │        48,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ F6 (Dense)                      │ (None, 84)             │        10,164 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 10)             │           850 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 60,074 (234.66 KB)
#  Trainable params: 60,074 (234.66 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Now compile and fit your model on your training data. Since this is a multiclass classification, the loss is not `binary_crossentropy` anymore, but `categorical_crossentropy`.

# %%
# TODO: Compile and fit your model
import os

# os.environ['KMP_DUPLICATE_LIB_OK']='True' #https://stackoverflow.com/questions/53014306/error-15-initializing-libiomp5-dylib-but-found-libiomp5-dylib-already-initial


from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import TensorBoard

model = lenet5()

model.compile(optimizer='adam', loss= 'categorical_crossentropy', metrics=['accuracy'])

# Define now our callbacks
# callbacks = [EarlyStopping(monitor='val_loss', patience=10), TensorBoard(log_dir='./keras-logs', histogram_freq=0, write_graph=True, write_images=True)]
callbacks = [EarlyStopping(monitor='val_loss', patience=10)]

# Finally fit the model
model.fit(x=X_train_norm, y=y_train_cat, validation_data=(X_test_norm, y_test_cat), epochs=100, batch_size=2048, callbacks=callbacks)
# Out:
# Epoch 1/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - accuracy: 0.3609 - loss: 2.0078 - val_accuracy: 0.6299 - val_loss: 0.9394
# Epoch 2/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.6877 - loss: 0.8353 - val_accuracy: 0.7436 - val_loss: 0.6934
# Epoch 3/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7593 - loss: 0.6432 - val_accuracy: 0.7663 - val_loss: 0.6079
# Epoch 4/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7896 - loss: 0.5658 - val_accuracy: 0.7937 - val_loss: 0.5571
# Epoch 5/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8064 - loss: 0.5233 - val_accuracy: 0.8083 - val_loss: 0.5174
# Epoch 6/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8244 - loss: 0.4775 - val_accuracy: 0.8176 - val_loss: 0.4969
# Epoch 7/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8322 - loss: 0.4610 - val_accuracy: 0.8230 - val_loss: 0.4819
# Epoch 8/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8393 - loss: 0.4415 - val_accuracy: 0.8341 - val_loss: 0.4577
# Epoch 9/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8508 - loss: 0.4172 - val_accuracy: 0.8413 - val_loss: 0.4403
# Epoch 10/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8490 - loss: 0.4155 - val_accuracy: 0.8414 - val_loss: 0.4338
# Epoch 11/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8575 - loss: 0.3987 - val_accuracy: 0.8410 - val_loss: 0.4370
# Epoch 12/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8549 - loss: 0.4019 - val_accuracy: 0.8330 - val_loss: 0.4471
# Epoch 13/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8555 - loss: 0.3963 - val_accuracy: 0.8537 - val_loss: 0.4082
# Epoch 14/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8640 - loss: 0.3807 - val_accuracy: 0.8538 - val_loss: 0.4056
# Epoch 15/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8663 - loss: 0.3747 - val_accuracy: 0.8575 - val_loss: 0.3993
# Epoch 16/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8687 - loss: 0.3626 - val_accuracy: 0.8542 - val_loss: 0.4038
# Epoch 17/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8690 - loss: 0.3615 - val_accuracy: 0.8611 - val_loss: 0.3922
# Epoch 18/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8724 - loss: 0.3568 - val_accuracy: 0.8571 - val_loss: 0.3974
# Epoch 19/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8735 - loss: 0.3519 - val_accuracy: 0.8666 - val_loss: 0.3795
# Epoch 20/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8749 - loss: 0.3488 - val_accuracy: 0.8671 - val_loss: 0.3791
# Epoch 21/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8771 - loss: 0.3440 - val_accuracy: 0.8673 - val_loss: 0.3730
# Epoch 22/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8771 - loss: 0.3387 - val_accuracy: 0.8640 - val_loss: 0.3812
# Epoch 23/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8772 - loss: 0.3395 - val_accuracy: 0.8707 - val_loss: 0.3680
# Epoch 24/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8800 - loss: 0.3310 - val_accuracy: 0.8687 - val_loss: 0.3696
# Epoch 25/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8816 - loss: 0.3292 - val_accuracy: 0.8694 - val_loss: 0.3691
# Epoch 26/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8836 - loss: 0.3254 - val_accuracy: 0.8670 - val_loss: 0.3744
# Epoch 27/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.8836 - loss: 0.3275 - val_accuracy: 0.8696 - val_loss: 0.3663
# Epoch 28/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8847 - loss: 0.3227 - val_accuracy: 0.8701 - val_loss: 0.3636
# Epoch 29/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8837 - loss: 0.3194 - val_accuracy: 0.8746 - val_loss: 0.3562
# Epoch 30/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8862 - loss: 0.3154 - val_accuracy: 0.8769 - val_loss: 0.3528
# Epoch 31/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8883 - loss: 0.3098 - val_accuracy: 0.8719 - val_loss: 0.3598
# Epoch 32/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8868 - loss: 0.3117 - val_accuracy: 0.8751 - val_loss: 0.3529
# Epoch 33/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8892 - loss: 0.3067 - val_accuracy: 0.8766 - val_loss: 0.3472
# Epoch 34/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8915 - loss: 0.3043 - val_accuracy: 0.8745 - val_loss: 0.3553
# Epoch 35/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8901 - loss: 0.3065 - val_accuracy: 0.8768 - val_loss: 0.3493
# Epoch 36/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8898 - loss: 0.3064 - val_accuracy: 0.8697 - val_loss: 0.3572
# Epoch 37/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8886 - loss: 0.3050 - val_accuracy: 0.8796 - val_loss: 0.3397
# Epoch 38/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8894 - loss: 0.3013 - val_accuracy: 0.8814 - val_loss: 0.3364
# Epoch 39/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8926 - loss: 0.2926 - val_accuracy: 0.8800 - val_loss: 0.3374
# Epoch 40/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8935 - loss: 0.2954 - val_accuracy: 0.8812 - val_loss: 0.3367
# Epoch 41/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8949 - loss: 0.2919 - val_accuracy: 0.8794 - val_loss: 0.3412
# Epoch 42/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8948 - loss: 0.2908 - val_accuracy: 0.8820 - val_loss: 0.3324
# Epoch 43/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8960 - loss: 0.2841 - val_accuracy: 0.8806 - val_loss: 0.3379
# Epoch 44/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8954 - loss: 0.2896 - val_accuracy: 0.8749 - val_loss: 0.3431
# Epoch 45/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8966 - loss: 0.2840 - val_accuracy: 0.8838 - val_loss: 0.3324
# Epoch 46/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9002 - loss: 0.2760 - val_accuracy: 0.8780 - val_loss: 0.3419
# Epoch 47/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8981 - loss: 0.2804 - val_accuracy: 0.8781 - val_loss: 0.3447
# Epoch 48/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8979 - loss: 0.2835 - val_accuracy: 0.8821 - val_loss: 0.3288
# Epoch 49/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9017 - loss: 0.2727 - val_accuracy: 0.8797 - val_loss: 0.3392
# Epoch 50/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.8967 - loss: 0.2826 - val_accuracy: 0.8825 - val_loss: 0.3293
# Epoch 51/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8992 - loss: 0.2768 - val_accuracy: 0.8806 - val_loss: 0.3312
# Epoch 52/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9015 - loss: 0.2692 - val_accuracy: 0.8853 - val_loss: 0.3233
# Epoch 53/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9018 - loss: 0.2655 - val_accuracy: 0.8869 - val_loss: 0.3206
# Epoch 54/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9035 - loss: 0.2656 - val_accuracy: 0.8844 - val_loss: 0.3199
# Epoch 55/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9014 - loss: 0.2694 - val_accuracy: 0.8825 - val_loss: 0.3272
# Epoch 56/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8984 - loss: 0.2735 - val_accuracy: 0.8845 - val_loss: 0.3228
# Epoch 57/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9038 - loss: 0.2635 - val_accuracy: 0.8857 - val_loss: 0.3197
# Epoch 58/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9059 - loss: 0.2601 - val_accuracy: 0.8875 - val_loss: 0.3183
# Epoch 59/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9047 - loss: 0.2624 - val_accuracy: 0.8846 - val_loss: 0.3206
# Epoch 60/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9062 - loss: 0.2583 - val_accuracy: 0.8865 - val_loss: 0.3202
# Epoch 61/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9075 - loss: 0.2562 - val_accuracy: 0.8846 - val_loss: 0.3218
# Epoch 62/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9060 - loss: 0.2573 - val_accuracy: 0.8889 - val_loss: 0.3143
# Epoch 63/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9092 - loss: 0.2497 - val_accuracy: 0.8867 - val_loss: 0.3192
# Epoch 64/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9057 - loss: 0.2582 - val_accuracy: 0.8874 - val_loss: 0.3164
# Epoch 65/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9081 - loss: 0.2500 - val_accuracy: 0.8880 - val_loss: 0.3170
# Epoch 66/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9111 - loss: 0.2451 - val_accuracy: 0.8856 - val_loss: 0.3174
# Epoch 67/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9087 - loss: 0.2483 - val_accuracy: 0.8843 - val_loss: 0.3198
# Epoch 68/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9102 - loss: 0.2478 - val_accuracy: 0.8893 - val_loss: 0.3134
# Epoch 69/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9125 - loss: 0.2416 - val_accuracy: 0.8895 - val_loss: 0.3154
# Epoch 70/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9115 - loss: 0.2442 - val_accuracy: 0.8893 - val_loss: 0.3155
# Epoch 71/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9122 - loss: 0.2409 - val_accuracy: 0.8812 - val_loss: 0.3342
# Epoch 72/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9079 - loss: 0.2506 - val_accuracy: 0.8880 - val_loss: 0.3126
# Epoch 73/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9128 - loss: 0.2425 - val_accuracy: 0.8842 - val_loss: 0.3192
# Epoch 74/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9124 - loss: 0.2398 - val_accuracy: 0.8879 - val_loss: 0.3135
# Epoch 75/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9151 - loss: 0.2340 - val_accuracy: 0.8899 - val_loss: 0.3073
# Epoch 76/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9146 - loss: 0.2335 - val_accuracy: 0.8808 - val_loss: 0.3278
# Epoch 77/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9119 - loss: 0.2407 - val_accuracy: 0.8897 - val_loss: 0.3090
# Epoch 78/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9151 - loss: 0.2301 - val_accuracy: 0.8900 - val_loss: 0.3133
# Epoch 79/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9141 - loss: 0.2303 - val_accuracy: 0.8908 - val_loss: 0.3056
# Epoch 80/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9174 - loss: 0.2281 - val_accuracy: 0.8918 - val_loss: 0.3048
# Epoch 81/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9163 - loss: 0.2270 - val_accuracy: 0.8880 - val_loss: 0.3146
# Epoch 82/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9160 - loss: 0.2263 - val_accuracy: 0.8897 - val_loss: 0.3107
# Epoch 83/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9175 - loss: 0.2291 - val_accuracy: 0.8865 - val_loss: 0.3133
# Epoch 84/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9168 - loss: 0.2278 - val_accuracy: 0.8914 - val_loss: 0.3170
# Epoch 85/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9150 - loss: 0.2300 - val_accuracy: 0.8900 - val_loss: 0.3083
# Epoch 86/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9180 - loss: 0.2218 - val_accuracy: 0.8911 - val_loss: 0.3086
# Epoch 87/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9212 - loss: 0.2190 - val_accuracy: 0.8910 - val_loss: 0.3076
# Epoch 88/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9211 - loss: 0.2166 - val_accuracy: 0.8923 - val_loss: 0.3044
# Epoch 89/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9203 - loss: 0.2176 - val_accuracy: 0.8860 - val_loss: 0.3236
# Epoch 90/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9168 - loss: 0.2223 - val_accuracy: 0.8915 - val_loss: 0.3056
# Epoch 91/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9208 - loss: 0.2135 - val_accuracy: 0.8900 - val_loss: 0.3080
# Epoch 92/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9235 - loss: 0.2116 - val_accuracy: 0.8875 - val_loss: 0.3230
# Epoch 93/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9181 - loss: 0.2219 - val_accuracy: 0.8889 - val_loss: 0.3208
# Epoch 94/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9195 - loss: 0.2191 - val_accuracy: 0.8918 - val_loss: 0.3049
# Epoch 95/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9219 - loss: 0.2107 - val_accuracy: 0.8893 - val_loss: 0.3131
# Epoch 96/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9239 - loss: 0.2103 - val_accuracy: 0.8927 - val_loss: 0.3053
# Epoch 97/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9252 - loss: 0.2050 - val_accuracy: 0.8914 - val_loss: 0.3107
# Epoch 98/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9234 - loss: 0.2083 - val_accuracy: 0.8946 - val_loss: 0.3039
# Epoch 99/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9276 - loss: 0.2046 - val_accuracy: 0.8932 - val_loss: 0.3062
# Epoch 100/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9245 - loss: 0.2088 - val_accuracy: 0.8887 - val_loss: 0.3098

# %% [markdown]
# Have a look at the tensorboard and see if it gives a deeper understanding of your model.

# %% [markdown]
# Compute then the accuracy of your model. Is it better than a regular MLP used before?

# %%
# TODO: Compute the accuracy of your model
from sklearn.metrics import accuracy_score

batch_size = 1024
y_pred_train = to_categorical(model.predict(X_train_norm, batch_size=batch_size).argmax(axis=1), num_classes=10)
y_pred_test = to_categorical(model.predict(X_test_norm, batch_size=batch_size).argmax(axis=1), num_classes=10)

print('accuracy on train with NN:', accuracy_score(y_pred_train, y_train_cat))
print('accuracy on test with NN:', accuracy_score(y_pred_test, y_test_cat))
# Out:
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# accuracy on train with NN: 0.92205
# accuracy on test with NN: 0.8887

# %% [markdown]
# We will now add image augmentation to improve our results, especially we will try to reduce overfitting this way.
#
# To do so, you can use `ImageDataGenerator` from Keras that makes all the work for you (including rescaling), with the following parameter:
# * `horizontal_flip=True`
#
# For more info about how the `ImageDataGenerator` works, you can check out [this article](https://www.pyimagesearch.com/2019/07/08/keras-imagedatagenerator-and-data-augmentation/).
#
# Begin by creating an object `ImageDataGenerator` with this parameter.

# %%
# TODO: Instantiate an ImageDataGenerator object
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(horizontal_flip=True)

# %% [markdown]
# Finally, you can train your model using this generator, with the method `fit_generator` of your model and the method `flow` of your `ImageDataGenerator`.

# %%
# TODO: train your model
batch_size = 1024
model.fit_generator(datagen.flow(X_train_norm, y_train_cat, batch_size=batch_size),
                    validation_data=(X_test_norm, y_test_cat), callbacks=callbacks,
                    steps_per_epoch=len(X_train_norm) / batch_size, epochs=100)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-5da9cbf7d7d8> in <cell line: 0>()
#       1 # TODO: train your model
#       2 batch_size = 1024
# ----> 3 model.fit_generator(datagen.flow(X_train_norm, y_train_cat, batch_size=batch_size),
#       4                     validation_data=(X_test_norm, y_test_cat), callbacks=callbacks,
#       5                     steps_per_epoch=len(X_train_norm) / batch_size, epochs=100)
#
# AttributeError: 'Sequential' object has no attribute 'fit_generator'

# %% [markdown]
# Recompute the accuracy of your model, does it improve your performances with data augmentation?

# %%
# TODO: Compute the accuracy of your model
from sklearn.metrics import accuracy_score

batch_size=1024
y_pred_train = to_categorical(model.predict(X_train_norm, batch_size=batch_size).argmax(axis=1), num_classes=10)
y_pred_test = to_categorical(model.predict(X_test_norm, batch_size=batch_size).argmax(axis=1), num_classes=10)

print('accuracy on train with CNN:', accuracy_score(y_pred_train, y_train_cat))
print('accuracy on test with CNN:', accuracy_score(y_pred_test, y_test_cat))
# Out:
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# accuracy on train with CNN: 0.92205
# accuracy on test with CNN: 0.8887

# %% [markdown]
# You can now try to improve even more your results. For example, add more parameters to your `ImageDataGenerator`, play with some hyperparameters, and so on...
